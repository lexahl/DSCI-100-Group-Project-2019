# %%
suppressWarnings(library(tidyverse))
suppressWarnings(library(testthat))
suppressWarnings(library(digest))
suppressWarnings(library(repr))
suppressWarnings(library(caret))

# %%
suppressWarnings(install.packages("GGally"))
suppressWarnings(library(GGally))
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
1
# Out:
# [1] 1

# %%
white_wine <- read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", 
                    delim=";", skip=1,
                    col_names=c("fixed_acidity","volatile_acidity","citric_acid",
                                "residual_sugar","chlorides","free_SO2","total_SO2",
                                "density","pH","sulphates","alcohol","quality"))
red_wine <- read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv",
                    delim=";", skip=1,
                    col_names=c("fixed_acidity","volatile_acidity","citric_acid",
                                "residual_sugar","chlorides","free_SO2","total_SO2",
                                "density","pH","sulphates","alcohol","quality"))
# Out:
# Parsed with column specification:
# cols(
#   fixed_acidity = col_double(),
#   volatile_acidity = col_double(),
#   citric_acid = col_double(),
#   residual_sugar = col_double(),
#   chlorides = col_double(),
#   free_SO2 = col_double(),
#   total_SO2 = col_double(),
#   density = col_double(),
#   pH = col_double(),
#   sulphates = col_double(),
#   alcohol = col_double(),
#   quality = col_integer()
# )
# Parsed with column specification:
# cols(
#   fixed_acidity = col_double(),
#   volatile_acidity = col_double(),
#   citric_acid = col_double(),
#   residual_sugar = col_double(),
#   chlorides = col_double(),
#   free_SO2 = col_double(),
#   total_SO2 = col_integer(),
#   density = col_double(),
#   pH = col_double(),
#   sulphates = col_double(),
#   alcohol = col_double(),
#   quality = col_integer()
# )
# Warning message:
# “2 parsing failures.
# row # A tibble: 2 x 5 col     row col       expected               actual file                            expected   <int> <chr>     <chr>                  <chr>  <chr>                           actual 1  1296 total_SO2 no trailing characters .5     'https://archive.ics.uci.edu/m… file 2  1297 total_SO2 no trailing characters .5     'https://archive.ics.uci.edu/m…
# ”

# %%
head(red_wine)
# Out:
#   fixed_acidity volatile_acidity citric_acid residual_sugar chlorides free_SO2
# 1  7.4          0.70             0.00        1.9            0.076     11
# 2  7.8          0.88             0.00        2.6            0.098     25
# 3  7.8          0.76             0.04        2.3            0.092     15
# 4 11.2          0.28             0.56        1.9            0.075     17
# 5  7.4          0.70             0.00        1.9            0.076     11
# 6  7.4          0.66             0.00        1.8            0.075     13
#   total_SO2 density pH   sulphates alcohol quality
# 1 34        0.9978  3.51 0.56      9.4     5
# 2 67        0.9968  3.20 0.68      9.8     5
# 3 54        0.9970  3.26 0.65      9.8     5
# 4 60        0.9980  3.16 0.58      9.8     6
# 5 34        0.9978  3.51 0.56      9.4     5
# 6 40        0.9978  3.51 0.56      9.4     5

# %%
head(white_wine)
# Out:
#   fixed_acidity volatile_acidity citric_acid residual_sugar chlorides free_SO2
# 1 7.0           0.27             0.36        20.7           0.045     45
# 2 6.3           0.30             0.34         1.6           0.049     14
# 3 8.1           0.28             0.40         6.9           0.050     30
# 4 7.2           0.23             0.32         8.5           0.058     47
# 5 7.2           0.23             0.32         8.5           0.058     47
# 6 8.1           0.28             0.40         6.9           0.050     30
#   total_SO2 density pH   sulphates alcohol quality
# 1 170       1.0010  3.00 0.45       8.8    6
# 2 132       0.9940  3.30 0.49       9.5    6
# 3  97       0.9951  3.26 0.44      10.1    6
# 4 186       0.9956  3.19 0.40       9.9    6
# 5 186       0.9956  3.19 0.40       9.9    6
# 6  97       0.9951  3.26 0.44      10.1    6

# %%
nrow(white_wine)
nrow(red_wine)
# Out:
# [1] 4898
# [1] 1599

# %%
nine <- white_wine %>%
    filter(quality==9)

# %%
nine
# Out:
#   fixed_acidity volatile_acidity citric_acid residual_sugar chlorides free_SO2
# 1 9.1           0.27             0.45        10.6           0.035     28
# 2 6.6           0.36             0.29         1.6           0.021     24
# 3 7.4           0.24             0.36         2.0           0.031     27
# 4 6.9           0.36             0.34         4.2           0.018     57
# 5 7.1           0.26             0.49         2.2           0.032     31
#   total_SO2 density pH   sulphates alcohol quality
# 1 124       0.99700 3.20 0.46      10.4    9
# 2  85       0.98965 3.41 0.61      12.4    9
# 3 139       0.99055 3.28 0.48      12.5    9
# 4 119       0.98980 3.28 0.36      12.7    9
# 5 113       0.99030 3.37 0.42      12.9    9

# %%
options(repr.plot.width=5.5,repr.plot.height=4.5)

walcohol<-ggplot(wwine, aes(x = quality, y = alcohol)) + 
    geom_point(alpha=0.1,position = "jitter") +
    xlab("Quality") + 
    ylab("Alcohol (%)") +
    ggtitle("Alcohol vs Quality (white wine)")
walcohol

ralcohol<-ggplot(rwine, aes(x = quality, y = alcohol)) + 
    geom_point(alpha=0.1,position = "jitter") +
    xlab("Quality") + 
    ylab("Alcohol (%)") +
    ggtitle("Alcohol vs Quality (red wine)")
ralcohol
# Out:
# plot without title
# plot without title

# %%
print(1)
# Out:
# [1] 1

# %%
options(repr.plot.width=5.5,repr.plot.height=4.5)
red_wine <- red_wine %>% 
  select(fixed_acidity:alcohol, quality)
glimpse(red_wine)

lots <- ggpairs(red_wine, mapping = ggplot2::aes())
# Out:
# Observations: 1,599
# Variables: 12
# $ fixed_acidity    <dbl> 7.4, 7.8, 7.8, 11.2, 7.4, 7.4, 7.9, 7.3, 7.8, 7.5,...
# $ volatile_acidity <dbl> 0.700, 0.880, 0.760, 0.280, 0.700, 0.660, 0.600, 0...
# $ citric_acid      <dbl> 0.00, 0.00, 0.04, 0.56, 0.00, 0.00, 0.06, 0.00, 0....
# $ residual_sugar   <dbl> 1.9, 2.6, 2.3, 1.9, 1.9, 1.8, 1.6, 1.2, 2.0, 6.1, ...
# $ chlorides        <dbl> 0.076, 0.098, 0.092, 0.075, 0.076, 0.075, 0.069, 0...
# $ free_SO2         <dbl> 11, 25, 15, 17, 11, 13, 15, 15, 9, 17, 15, 17, 16,...
# $ total_SO2        <int> 34, 67, 54, 60, 34, 40, 59, 21, 18, 102, 65, 102, ...
# $ density          <dbl> 0.9978, 0.9968, 0.9970, 0.9980, 0.9978, 0.9978, 0....
# $ pH               <dbl> 3.51, 3.20, 3.26, 3.16, 3.51, 3.51, 3.30, 3.39, 3....
# $ sulphates        <dbl> 0.56, 0.68, 0.65, 0.58, 0.56, 0.56, 0.46, 0.47, 0....
# $ alcohol          <dbl> 9.4, 9.8, 9.8, 9.8, 9.4, 9.4, 9.4, 10.0, 9.5, 10.5...
# $ quality          <int> 5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7,...

# %%
options(repr.plot.width=10,repr.plot.height=10)
lots
# Out:
# Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing non-finite values (stat_density).”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message in (function (data, mapping, alignPercent = 0.6, method = "pearson", :
# “Removed 2 rows containing missing values”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title
